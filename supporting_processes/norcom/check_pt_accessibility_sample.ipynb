# %%
from pathlib import Path

import pandas as pd

# %%
input_path = Path(r'I:\NorMITs NorCOM\Import')

# %%
# read in the processed nts hh dataset 
nts_data = pd.read_csv(input_path / 'NTS' / 'nts_hh_data_v2.csv')

# %%
nts_data.head()
# Out:
#         psuid  psugor_b02id  psucounty_b01id  surveyyear hholdoslaua_b01id  \
# 0  2002000001             7               80        2002         E09000023
# 1  2002000001             7               80        2002         E09000023
# 2  2002000001             7               80        2002         E09000023
# 3  2002000001             7               80        2002         E09000023
# 4  2002000001             7               80        2002         E09000023
#
#    hholdgor_b02id settlement2011ew_b01id  hholdareatype2_b01id  \
# 0               7                     A1                     1
# 1               7                     A1                     1
# 2               7                     A1                     1
# 3               7                     A1                     1
# 4               7                     A1                     1
#
#    hholdua1998_b01id  hholdua2009_b01id  ...  deflated_total_cost  \
# ...

# %%
nts_data.columns
# Out:
# Index(['psuid', 'psugor_b02id', 'psucounty_b01id', 'surveyyear',
#        'hholdoslaua_b01id', 'hholdgor_b02id', 'settlement2011ew_b01id',
#        'hholdareatype2_b01id', 'hholdua1998_b01id', 'hholdua2009_b01id',
#        'hholdnumadults', 'hholdnumchildren', 'numcarvan', 'hhincome2002_b01id',
#        'w1', 'w2', 'w3', 'hholdcounty_b01id', 'walkbus', 'walkbus_b01id',
#        'getbus_b01id', 'walkrail', 'walkrail_b01id', 'walkrailalt',
#        'descta_b01id', 'hholdareatype1_b01id', 'hholdua_b01id',
#        'hholdareatype_b01id', 'hholdruc2011_b01id', 'tfn_at', 'hh_type',
#        'hh_child', 'ns', 'hh_income', 'householdid', 'rpi', '2023_deflator',
#        'hh_income_2023', 'purchase_cost', 'maintenance_cost', 'fuel_cost',
#        'insurance_cost', 'total_cost', 'gdp_pc', 'gdp_2023', 'gdp_deflator',
#        'deflated_purchase_cost', 'deflated_maintenance_cost',
#        'deflated_fuel_cost', 'deflated_insurance_cost', 'deflated_total_cost',
# ...

# %%
pt_access_cols = ['walkrail_b01id', 'descta_b01id']

# %%
nts_data.groupby(pt_access_cols).agg({'psuid': 'count'})
# Out:
#                              psuid
# walkrail_b01id descta_b01id
# -10            -10           60833
#  1              1             5038
#                 2              236
#                 3              385
#  2              1             8394
#                 2              364
#                 3              589
#  3              1            19693
#                 2              864
#                 3             1400
#  4              1            13385
#                 2              664
#                 3              905
#  5              1            31211
#                 2             1645
#                 3             2519
