# %%
from pathlib import Path
import joblib

# %%
model_path = Path(r"I:\NorMITs NorCOM\AECOM working\v15\0v1\output\final_model.pkl")

# %%
with open(model_path, 'rb') as model_file:
    model_data = joblib.load(model_file)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-4315638e7dc4> in <module>
#       1 with open(model_path, 'rb') as model_file:
# ----> 2     model_data = joblib.load(model_file)
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in load(filename, mmap_mode)
#     573         filename = getattr(fobj, 'name', '')
#     574         with _read_fileobject(fobj, filename, mmap_mode) as fobj:
# --> 575             obj = _unpickle(fobj)
#     576     else:
#     577         with open(filename, 'rb') as f:
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in _unpickle(fobj, filename, mmap_mode)
#     502     obj = None
#     503     try:
# --> 504         obj = unpickler.load()
#     505         if unpickler.compat_mode:
#     506             warnings.warn("The file '%s' has been generated with a "
#
# C:\ProgramData\Anaconda3\lib\pickle.py in load(self)
#    1210                     raise EOFError
#    1211                 assert isinstance(key, bytes_types)
# -> 1212                 dispatch[key[0]](self)
#    1213         except _Stop as stopinst:
#    1214             return stopinst.value
#
# KeyError: 255

# %%
type(model_data)
# Out:
# numpy.ndarray

# %%
model_data = joblib.load(model_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-d9f8ab7c6978> in <module>
# ----> 1 model_data = joblib.load(model_file)
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in load(filename, mmap_mode)
#     572         fobj = filename
#     573         filename = getattr(fobj, 'name', '')
# --> 574         with _read_fileobject(fobj, filename, mmap_mode) as fobj:
#     575             obj = _unpickle(fobj)
#     576     else:
#
# C:\ProgramData\Anaconda3\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\numpy_pickle_utils.py in _read_fileobject(fileobj, filename, mmap_mode)
#     122     """
#     123     # Detect if the fileobj contains compressed data.
# --> 124     compressor = _detect_compressor(fileobj)
#     125
#     126     if compressor == 'compat':
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\numpy_pickle_utils.py in _detect_compressor(fileobj)
#      67         # Peek allows to read those bytes without moving the cursor in the
#      68         # file whic.
# ---> 69         first_bytes = fileobj.peek(max_prefix_len)
#      70     else:
#      71         # Fallback to seek if the fileobject is not peekable.
#
# ValueError: peek of closed file

# %%
model_data
# Out:
# array(['tfn_at_v2_1', 'tfn_at_v2_2', 'tfn_at_v2_3', 'tfn_at_v2_5',
#        'tfn_at_v2_6', 'hh_children_seg_2', 'ns_2', 'ns_3', 'ns_4', 'ns_5',
#        'hh_adults_seg_1', 'hh_adults_seg_3', 'hh_income_banded_v3_1',
#        'hh_income_banded_v3_2', 'hh_income_banded_v3_3',
#        'hh_income_banded_v3_4', 'hh_income_banded_v3_6',
#        'hh_income_banded_v3_7', 'walkrail_b01id_1', 'walkrail_b01id_2',
#        'walkrail_b01id_3', 'walkrail_b01id_4', 'descta_b01id_2',
#        'descta_b01id_3'], dtype=object)

# %%
model_data.params()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-78669672e0cf> in <module>
# ----> 1 model_data.params()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'params'
